# %%
from transformers import pipeline

# %%
import os
os.environ['HF_HOME'] = '/srv/william/huggingface'
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
print("HF_HOME:", os.environ.get('HF_HOME'))
print("HF_ENDPOINT:", os.environ.get('HF_ENDPOINT'))
